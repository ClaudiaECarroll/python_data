# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %%
df_SAFI = pd.read_csv("/content/drive/MyDrive/workshop_data/SAFI_results.csv")

# %%
df_SAFI.head()
# Out:
#    Column1 A01_interview_date  A03_quest_no                 A04_start  \
# 0        0         17/11/2016             1  2017-03-23T09:49:57.000Z
# 1        1         17/11/2016             1  2017-04-02T09:48:16.000Z
# 2        2         17/11/2016             3  2017-04-02T14:35:26.000Z
# 3        3         17/11/2016             4  2017-04-02T14:55:18.000Z
# 4        4         17/11/2016             5  2017-04-02T15:10:35.000Z
#
#                     A05_end A06_province A07_district A08_ward A09_village  \
# 0  2017-04-02T17:29:08.000Z    Province1    District1    Ward2    Village2
# 1  2017-04-02T17:26:19.000Z    Province1    District1    Ward2    Village2
# 2  2017-04-02T17:26:53.000Z    Province1    District1    Ward2    Village2
# 3  2017-04-02T17:27:16.000Z    Province1    District1    Ward2    Village2
# 4  2017-04-02T17:27:35.000Z    Province1    District1    Ward2    Village2
#
#    A11_years_farm  ... F13_du_look_aftr_cows F_liv_count  G01_no_meals  \
# ...

# %%
df_SAFI.columns.values
# Out:
# array(['Column1', 'A01_interview_date', 'A03_quest_no', 'A04_start',
#        'A05_end', 'A06_province', 'A07_district', 'A08_ward',
#        'A09_village', 'A11_years_farm', 'A12_agr_assoc',
#        'B11_remittance_money', 'B16_years_liv', 'B17_parents_liv',
#        'B18_sp_parents_liv', 'B19_grand_liv', 'B20_sp_grand_liv',
#        'B_no_membrs', 'C01_respondent_roof_type',
#        'C02_respondent_wall_type', 'C02_respondent_wall_type_other',
#        'C03_respondent_floor_type', 'C04_window_type',
#        'C05_buildings_in_compound', 'C06_rooms', 'C07_other_buildings',
#        'D_plots_count', 'E01_water_use', 'E17_no_enough_water',
#        'E19_period_use', 'E20_exper_other', 'E21_other_meth',
#        'E23_memb_assoc', 'E24_resp_assoc', 'E25_fees_water',
#        'E26_affect_conflicts', 'E_no_group_count', 'E_yes_group_count',
#        'F04_need_money', 'F05_money_source_other', 'F06_crops_contr',
#        'F08_emply_lab', 'F09_du_labour', 'F10_liv_owned_other',
# ...

# %%
#Removing codes from start of column headers

df_SAFI.columns = df_SAFI.columns.str.replace(r'^.*?_', '', regex=True)

# %%
df_SAFI.columns.values
# Out:
# array(['Column1', 'interview_date', 'quest_no', 'start', 'end',
#        'province', 'district', 'ward', 'village', 'years_farm',
#        'agr_assoc', 'remittance_money', 'years_liv', 'parents_liv',
#        'sp_parents_liv', 'grand_liv', 'sp_grand_liv', 'no_membrs',
#        'respondent_roof_type', 'respondent_wall_type',
#        'respondent_wall_type_other', 'respondent_floor_type',
#        'window_type', 'buildings_in_compound', 'rooms', 'other_buildings',
#        'plots_count', 'water_use', 'no_enough_water', 'period_use',
#        'exper_other', 'other_meth', 'memb_assoc', 'resp_assoc',
#        'fees_water', 'affect_conflicts', 'no_group_count',
#        'yes_group_count', 'need_money', 'money_source_other',
#        'crops_contr', 'emply_lab', 'du_labour', 'liv_owned_other',
#        'poultry', 'du_look_aftr_cows', 'liv_count', 'no_meals',
#        'members_count', 'note', 'gps:Accuracy', 'gps:Altitude',
# ...

# %%
#Checking column headers

df_SAFI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 55 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Column1                     131 non-null    int64
#  1   interview_date              131 non-null    object
#  2   quest_no                    131 non-null    int64
#  3   start                       131 non-null    object
#  4   end                         131 non-null    object
#  5   province                    131 non-null    object
#  6   district                    131 non-null    object
#  7   ward                        131 non-null    object
#  8   village                     131 non-null    object
#  9   years_farm                  131 non-null    int64
#  10  agr_assoc                   131 non-null    object
#  11  remittance_money            131 non-null    object
#  12  years_liv                   131 non-null    int64
# ...

# %%
df_SAFI = df_SAFI[['years_farm',
       'respondent_roof_type', 'respondent_wall_type',
       'respondent_floor_type', 'buildings_in_compound',
       'rooms', 'other_buildings',
        'plots_count', 'note',
        'memb_assoc']]

# %%
df_SAFI.head()
# Out:
#    years_farm respondent_roof_type respondent_wall_type respondent_floor_type  \
# 0          11                grass              muddaub                 earth
# 1           2                grass              muddaub                 earth
# 2          40        mabatisloping          burntbricks                cement
# 3           6        mabatisloping          burntbricks                 earth
# 4          18                grass          burntbricks                 earth
#
#    buildings_in_compound  rooms other_buildings  plots_count  note memb_assoc
# 0                      1      1              no            2   NaN        NaN
# 1                      1      1              no            3   NaN        yes
# 2                      1      1              no            1   NaN        NaN
# 3                      1      1              no            3   NaN        NaN
# 4                      1      1              no            2   NaN        NaN

# %%
df_SAFI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131 entries, 0 to 130
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   years_farm             131 non-null    int64
#  1   respondent_roof_type   131 non-null    object
#  2   respondent_wall_type   131 non-null    object
#  3   respondent_floor_type  131 non-null    object
#  4   buildings_in_compound  131 non-null    int64
#  5   rooms                  131 non-null    int64
#  6   other_buildings        131 non-null    object
#  7   plots_count            131 non-null    int64
#  8   note                   0 non-null      float64
#  9   memb_assoc             92 non-null     object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 10.4+ KB

# %%
df_SAFI['memb_assoc']
# Out:
# 0      NaN
# 1      yes
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 126     no
# 127     no
# 128     no
# 129    yes
# 130    NaN
# Name: memb_assoc, Length: 131, dtype: object

# %%
#Remove rows with a NaN value in a particular column

df_SAFI = df_SAFI[df_SAFI['memb_assoc'].notna()]

df_SAFI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92 entries, 1 to 129
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   years_farm             92 non-null     int64
#  1   respondent_roof_type   92 non-null     object
#  2   respondent_wall_type   92 non-null     object
#  3   respondent_floor_type  92 non-null     object
#  4   buildings_in_compound  92 non-null     int64
#  5   rooms                  92 non-null     int64
#  6   other_buildings        92 non-null     object
#  7   plots_count            92 non-null     int64
#  8   note                   0 non-null      float64
#  9   memb_assoc             92 non-null     object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 7.9+ KB

# %%
#Use dropna() to remove all columns with NaN values

df_SAFI.dropna(inplace=True, axis="columns")
df_SAFI.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 92 entries, 1 to 129
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   years_farm             92 non-null     int64
#  1   respondent_roof_type   92 non-null     object
#  2   respondent_wall_type   92 non-null     object
#  3   respondent_floor_type  92 non-null     object
#  4   buildings_in_compound  92 non-null     int64
#  5   rooms                  92 non-null     int64
#  6   other_buildings        92 non-null     object
#  7   plots_count            92 non-null     int64
#  8   memb_assoc             92 non-null     object
# dtypes: int64(4), object(5)
# memory usage: 7.2+ KB

# %%
# Save cleaned dataframe to a new csv file

df_SAFI.to_csv("/content/drive/MyDrive/workshop_data/SAFI_results_cleaned.csv")

# %%
#Using describe to count how many cells in a column have non-null values

df_SAFI['years_farm'].describe()

# %% [markdown]
# # Exercise!!

# %% [markdown]
# ## Create a new dataframe called SAFI_subset from the original SAFI_results.csv that contains the columns respondent_roof_type, respondent_wall_type, respondent_wall_type_other, and respondent_floor_type. Calculate the percentage of cells in the new dataframe that are null.
